# %% [markdown]
# Data de confianza en las instituciones - Quedarme con las 10 primeras columnas y con las que tengan el código P1$01 hasta P1$13

# %%
import pandas as pd

confianza_2022 = pd.read_csv('C:/Users/arica/Documents/GitHub/Qlab_Repositorio/Introducción a Machine Learning/Trabajo Final/Data/784-Modulo85/Enaho01B-2022-1.csv', encoding='ISO-8859-1')

data_2022
# Out:
# C:\Users\arica\AppData\Local\Temp\ipykernel_19952\4238889215.py:3: DtypeWarning: Columns (324,325) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2022 = pd.read_csv('C:/Users/arica/Documents/GitHub/Qlab_Repositorio/Introducción a Machine Learning/Trabajo Final/Data/784-Modulo85/Enaho01B-2022-1.csv', encoding='ISO-8859-1')
#         AÑO  MES  CONGLOME  VIVIENDA  HOGAR  CODPERSO  CODINFOR  UBIGEO  \
# 0      2022    1      5030         8     11         1         1   10201
# 1      2022    1      5030        17     11         2         2   10201
# 2      2022    1      5030        33     11         2         2   10201
# 3      2022    1      5030        50     11         1         1   10201
# 4      2022    1      5030        59     11         7         7   10201
# ...     ...  ...       ...       ...    ...       ...       ...     ...
# 34208  2022   12     20537       144     11         1         1  210106
# ...

# %%
Data de condición Socioeconómica de los peruanos

# %%
socioeconomic_2022 = pd.read_csv('C:/Users/arica/Documents/GitHub/Qlab_Repositorio/Introducción a Machine Learning/Trabajo Final/Data/784-Modulo01/Enaho01-2022-100.csv', encoding='ISO-8859-1')

socioeconomic_2022
# Out:
#         AÑO  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2022    2      5007         3     11   10101        4        4
# 1      2022    2      5007        12     11   10101        4        4
# 2      2022    2      5007        22     11   10101        4        4
# 3      2022    2      5007        31     11   10101        4        4
# 4      2022    2      5007        50     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 44117  2022    4     21001        32     11  210903        6        8
# 44118  2022    4     21001        33     11  210903        6        8
# 44119  2022    4     21001        34     11  210903        6        8
# 44120  2022    4     21001        35     11  210903        6        8
# 44121  2022    4     21001        36     11  210903        6        8
#
#        PERIODO  TIPENC  ...  NBI4  NBI5    FACTOR07 NCONGLOME SUB_CONGLOME  \
# ...
